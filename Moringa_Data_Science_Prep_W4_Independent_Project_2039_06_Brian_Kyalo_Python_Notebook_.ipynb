# %%
import pandas as pd
import numpy as np

# %%
Auto=pd.read_csv('/content/Autolib_dataset (2).csv')

# %%
Auto
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
Auto

# %%
# information aboout the dataset
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   ID                   5000 non-null   object
#  9   Kind                 5000 non-null   object
#  10  Geo point            5000 non-null   object
#  11  Postal code          5000 non-null   int64
#  12  Public name          5000 non-null   object
#  13  Rental status        5000 non-null   object
#  14  Slots                5000 non-null   int64
# ...

# %%
Auto.isnull().sum()
# Out:
# Address                0
# Cars                   0
# Bluecar counter        0
# Utilib counter         0
# Utilib 1.4 counter     0
# Charge Slots           0
# Charging Status        0
# City                   0
# ID                     0
# Kind                   0
# Geo point              0
# Postal code            0
# Public name            0
# Rental status          0
# Slots                  0
# Station type           0
# Status                 0
# Subscription status    0
# hour                   0
# minute                 0
# Date                   0
# dtype: int64

# %%
Auto.shape
# Out:
# (5000, 21)

# %%
##dropping null values
all_rows_all_na = Auto.dropna(how="all")
all_rows_all_na.shape
# Out:
# (5000, 21)

# %%
Auto.drop('Displayed comment',axis=1,inplace=True)

# %%
Auto.drop('Scheduled at',axis=1,inplace=True)

# %%
Auto.duplicated().sum()
# Out:
# 0

# %%
#combining the date
Auto['Date']=pd.to_datetime(Auto[['year','month','day']])

# %%
a=Auto[(Auto['City']=='Paris') &(Auto['Bluecar counter']>0) & (Auto['Rental status']=='operational')]
a

# %%
Auto
# Out:
#                                  Address  Cars  ...  minute       Date
# 0                    2 Avenue de Suffren     0  ...      43 2018-04-08
# 1              145 Rue Raymond Losserand     6  ...      24 2018-04-06
# 2       2 Avenue John Fitzgerald Kennedy     3  ...      14 2018-04-03
# 3                 51 Rue Eug̬ne Oudin̩     3  ...      37 2018-04-04
# 4     6 avenue de la Porte de Champerret     3  ...      23 2018-04-08
# ...                                  ...   ...  ...     ...        ...
# 4995                 8 avenue M̩nelotte     2  ...      26 2018-04-06
# 4996                   37 rue de Dantzig     4  ...      56 2018-04-04
# 4997                      142 rue du Bac     1  ...       1 2018-04-01
# 4998         2 avenue du Val de Fontenay     2  ...      27 2018-04-04
# 4999                 5 Rue Henry Brisson     4  ...       2 2018-04-08
#
# [5000 rows x 24 columns]

# %% [markdown]
# MOST POPULAR HOUR FOR picking the car. researchrch question

# %%
popular_hour=Auto[(Auto['City']=='Paris') & (Auto['Bluecar counter']>0) & (Auto['Rental status']=='operational')&(Auto['month']==4)]
popular_hour.head()
popular_hour=df2_paris.groupby(['hour'])['Bluecar counter'].sum()
popular_hour.sort_values(ascending=False).head(1)
# Out:
# hour
# 21    268
# Name: Bluecar counter, dtype: int64

# %% [markdown]
# Question2.What station is the most popular?
# Overall?
# At the most popular picking hour?

# %%
####most popular station
Auto['Station type'].value_counts()
# Out:
# station         4615
# full_station     382
# subs_center        3
# Name: Station type, dtype: int64

# %%
Auto['hour'].value_counts()

# %% [markdown]
# Most popular station at picking hour

# %%
pickig_hour=Auto.loc[(Auto['Bluecar counter']) |(Auto['Utilib 1.4 counter']) |(Auto['Utilib counter'])&(Auto['Rental status']=='operational') &(Auto['hour']==21) & (Auto['Station type'])]
x=pickig_hour['Kind'].value_counts()
x
# Out:
# STATION    3243
# SPACE       272
# PARKING     111
# Name: Kind, dtype: int64

# %% [markdown]
# What postal code is the most popular for picking up Blue cars? Does the most popular station belong to that postal code?

# %%
address=Auto.groupby(['Bluecar counter'])['Postal code'].value_counts().sort_values(ascending=False)
address.head(1)
# Out:
# Bluecar counter  Postal code
# 0                75008          94
# Name: Postal code, dtype: int64

# %% [markdown]
# most postal code at the picking hour for bluecars.

# %%
postal_code=Auto.loc[(Auto['Bluecar counter'])&(Auto['Rental status']=='operational') &(Auto['hour']==17) &(Auto['Postal code'])]
#postal_code['hour'].value_counts()
postal_code['Postal code'].value_counts().head(1)
# Out:
# 75017    10
# Name: Postal code, dtype: int64

# %% [markdown]
# most popular hour for returning cars

# %%
#most popular hour for returning cars
df_returning = Auto[(Auto['Cars']>0) & (Auto['Rental status']=='operational')]
df_returning
popular_hour = df_returning.groupby(['Cars'])['hour'].value_counts().sort_values(ascending=False)
popular_hour.head(1)
# Out:
# Cars  hour
# 1     18      40
# Name: hour, dtype: int64
